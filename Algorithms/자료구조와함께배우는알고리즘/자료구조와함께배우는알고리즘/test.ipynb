# %%
import hashlib 
capacity = 2
class Text:
    def __init__(self):
        self.text = "hello"
key = Text()

sha256_param = str(key).encode()
sha256_param.hexdigest()
# int_param = hashlib.sha256(sha256_param).hexdigest()
# (int(int_param, 16) % capacity)
# Out:
# '<__main__.Text object at 0x109f249d0>'
